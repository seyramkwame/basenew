# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data
df = pd.read_csv("./DATA/HR-Employee-Attrition.csv")

# %%
df.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
#Beakdown of distance from home by job and attrition
df.groupby(['JobRole', 'Attrition'])['DistanceFromHome'].mean()
# Out:
# JobRole                    Attrition
# Healthcare Representative  No            9.204918
#                            Yes          17.666667
# Human Resources            No            6.600000
#                            Yes          13.416667
# Laboratory Technician      No            9.329949
#                            Yes           9.661290
# Manager                    No            7.927835
#                            Yes          10.000000
# Manufacturing Director     No            9.533333
#                            Yes           8.800000
# Research Director          No            8.474359
#                            Yes           7.000000
# Research Scientist         No            8.869388
#                            Yes           9.765957
# Sales Executive            No            9.026022
#                            Yes          12.649123
# Sales Representative       No            9.000000
#                            Yes           8.151515
# ...

# %%
#Average monthly income by education and attrition
df.groupby(['Education', 'Attrition'])['MonthlyIncome'].mean()
# Out:
# Education  Attrition
# 1          No           5926.129496
#            Yes          4360.161290
# 2          No           6586.058824
#            Yes          4282.545455
# 3          No           6882.919662
#            Yes          4770.242424
# 4          No           7087.814706
#            Yes          5335.155172
# 5          No           8559.906977
#            Yes          5850.200000
# Name: MonthlyIncome, dtype: float64

# %%
#Assignment 3
sns.countplot(x='JobRole', hue='Attrition', data=df)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
sns.boxplot(x='Education', y='MonthlyIncome', hue='Attrition', data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='MonthlyIncome'>

# %%
plt.hist(df[df['Attrition'] == 'Yes']['Age'], alpha=0.5, label='Attrition = Yes')
plt.hist(df[df['Attrition'] == 'No']['Age'], alpha=0.5, label='Attrition = No')
plt.legend(loc='upper right')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
